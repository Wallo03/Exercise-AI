# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('iris.data', header=None)
df.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']
df
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.corr()
# Out:
# C:\Users\libero.bo\AppData\Local\Temp\ipykernel_14996\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.109369      0.871754     0.817954
# sepal width      -0.109369     1.000000     -0.420516    -0.356544
# petal length      0.871754    -0.420516      1.000000     0.962757
# petal width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# C:\Users\libero.bo\AppData\Local\Temp\ipykernel_14996\621126171.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
y = df['class']
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: class, Length: 150, dtype: object

# %%
X = df[['sepal length', 'sepal width', 'petal length', 'petal width']]
X
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size = 0.3, 
                                                    random_state = 0
                                                    )

# %%
X_train.shape, X_test.shape
# Out:
# ((105, 4), (45, 4))

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
X_test
# Out:
#      sepal length  sepal width  petal length  petal width
# 114           5.8          2.8           5.1          2.4
# 62            6.0          2.2           4.0          1.0
# 33            5.5          4.2           1.4          0.2
# 107           7.3          2.9           6.3          1.8
# 7             5.0          3.4           1.5          0.2
# 100           6.3          3.3           6.0          2.5
# 40            5.0          3.5           1.3          0.3
# 86            6.7          3.1           4.7          1.5
# 76            6.8          2.8           4.8          1.4
# 71            6.1          2.8           4.0          1.3
# 134           6.1          2.6           5.6          1.4
# 51            6.4          3.2           4.5          1.5
# 73            6.1          2.8           4.7          1.2
# 54            6.5          2.8           4.6          1.5
# 63            6.1          2.9           4.7          1.4
# 37            4.9          3.1           1.5          0.1
# 78            6.0          2.9           4.5          1.5
# 90            5.5          2.6           4.4          1.2
# 45            4.8          3.0           1.4          0.3
# 16            5.4          3.9           1.3          0.4
# 121           5.6          2.8           4.9          2.0
# 66            5.6          3.0           4.5          1.5
# 24            4.8          3.4           1.9          0.2
# 8             4.4          2.9           1.4          0.2
# 126           6.2          2.8           4.8          1.8
# 22            4.6          3.6           1.0          0.2
# 44            5.1          3.8           1.9          0.4
# 97            6.2          2.9           4.3          1.3
# 93            5.0          2.3           3.3          1.0
# 26            5.0          3.4           1.6          0.4
# 137           6.4          3.1           5.5          1.8
# 84            5.4          3.0           4.5          1.5
# 27            5.2          3.5           1.5          0.2
# 127           6.1          3.0           4.9          1.8
# 132           6.4          2.8           5.6          2.2
# 59            5.2          2.7           3.9          1.4
# 18            5.7          3.8           1.7          0.3
# 83            6.0          2.7           5.1          1.6
# 61            5.9          3.0           4.2          1.5
# 92            5.8          2.6           4.0          1.2
# 112           6.8          3.0           5.5          2.1
# 2             4.7          3.2           1.3          0.2
# 141           6.9          3.1           5.1          2.3
# 43            5.0          3.5           1.6          0.6
# 10            5.4          3.7           1.5          0.2

# %%
res_df = pd.DataFrame(data=list(zip(y_pred, y_test)),columns=['predicted', 'real'])
res_df
# Out:
#           predicted             real
# 0    Iris-virginica   Iris-virginica
# 1   Iris-versicolor  Iris-versicolor
# 2       Iris-setosa      Iris-setosa
# 3    Iris-virginica   Iris-virginica
# 4       Iris-setosa      Iris-setosa
# 5    Iris-virginica   Iris-virginica
# 6       Iris-setosa      Iris-setosa
# 7   Iris-versicolor  Iris-versicolor
# 8   Iris-versicolor  Iris-versicolor
# 9   Iris-versicolor  Iris-versicolor
# 10   Iris-virginica   Iris-virginica
# 11  Iris-versicolor  Iris-versicolor
# 12  Iris-versicolor  Iris-versicolor
# 13  Iris-versicolor  Iris-versicolor
# 14  Iris-versicolor  Iris-versicolor
# 15      Iris-setosa      Iris-setosa
# 16  Iris-versicolor  Iris-versicolor
# 17  Iris-versicolor  Iris-versicolor
# 18      Iris-setosa      Iris-setosa
# 19      Iris-setosa      Iris-setosa
# 20   Iris-virginica   Iris-virginica
# 21  Iris-versicolor  Iris-versicolor
# 22      Iris-setosa      Iris-setosa
# 23      Iris-setosa      Iris-setosa
# 24   Iris-virginica   Iris-virginica
# 25      Iris-setosa      Iris-setosa
# 26      Iris-setosa      Iris-setosa
# 27  Iris-versicolor  Iris-versicolor
# 28  Iris-versicolor  Iris-versicolor
# 29      Iris-setosa      Iris-setosa
# 30   Iris-virginica   Iris-virginica
# 31  Iris-versicolor  Iris-versicolor
# 32      Iris-setosa      Iris-setosa
# 33   Iris-virginica   Iris-virginica
# 34   Iris-virginica   Iris-virginica
# 35  Iris-versicolor  Iris-versicolor
# 36      Iris-setosa      Iris-setosa
# 37   Iris-virginica  Iris-versicolor
# 38  Iris-versicolor  Iris-versicolor
# 39  Iris-versicolor  Iris-versicolor
# 40   Iris-virginica   Iris-virginica
# 41      Iris-setosa      Iris-setosa
# 42   Iris-virginica   Iris-virginica
# 43      Iris-setosa      Iris-setosa
# 44      Iris-setosa      Iris-setosa

# %%
length = y_pred.shape[0] #  
x = np.linspace(0,length,length)

plt.figure(figsize=(10,7))
plt.plot(x, y_test, label='real y')
plt.plot(x, y_pred, label="predicted y'")
plt.legend(loc=2)

# %%
#X.to_csv('sample_data.csv', index=False)
